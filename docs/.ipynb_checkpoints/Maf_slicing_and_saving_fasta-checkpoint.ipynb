# %%
from Bio import AlignIO
from Bio.AlignIO import MafIO
import os
import pandas as pd

# %% [markdown]
# First, we will parse the maf alignment into AlignIO

# %%
# Parse the maf alignment
# THIS FILE CANNOT BE COMMITTED DUE TO BEING LARGE
alignment = AlignIO.parse('../data/small_subset/chr21.maf', 'maf')

# %% [markdown]
# We can now index the maf file using the following function:

# %%
idx = MafIO.MafIndex("../data/chr21.mafindex", '../data/small_subset/chr21.maf', "Homo_sapiens.chr21")

# %% [markdown]
# If we want to retrieve a 50 kb window, we can do so with the search method:

# %%
results = idx.search([20000000], [20050000])
AlignIO.write(results, '../results/small_subset/chr21_subset.fa', "fasta")
# Out:
# 15

# %% [markdown]
# We can also save each of the alignments separately:

# %%
results = idx.search([20000000], [20050000])
for i, j in enumerate(results):
    AlignIO.write(j, '../results/small_subset/individual_alignments/chr21_subset{}.fa'.format(i), "fasta")

# %% [markdown]
# And we can save the coordinates easily:

# %%
def get_coord_df(align):
    """
    Function for getting a data frame with the species, the
    start coordinates and a binary vector where 1 means a nt
    and 0 means a gap.
    """
    # Create an empty dataframe
    df = pd.DataFrame(columns = ['file', 'species', 'chr', 'start', 'gaps'])
    # For each of the alignments
    for i, align in enumerate(results):
        # Create empty dictionary
        dct = {'species':[], 'chr':[], 'start':[],'gaps':[]}
        # Write individual FASTA file
        AlignIO.write(align, '../results/small_subset/individual_alignments/chr21_subset{}.fa'.format(i), "fasta")
        # For each of the records
        for record in align:
            # Retrieve species
            dct['species'].append(record.name.split('.')[0])
            # Retrieve chromosome/contig
            dct['chr'].append('.'.join(record.name.split('.')[1:]))
            # Retrieve start coordinate
            dct['start'].append(record.annotations['start'])
            # Retrieve gaps encoded in a binary format
            dct['gaps'].append(''.join([str(0) if n=='-' else str(1) for n in record.seq]))
        # Convert dictionary to data frame
        file_df = pd.DataFrame.from_dict(dct)
        # Insert column mapping to the file
        file_df.insert(0, 'file', i, True)
        # Append rows to overall data frame
        df = df.append(file_df)
    return df

# %%
results = idx.search([20000000], [20050000])
get_coord_df(results)
# Out:
#   file                  species         chr     start  \
# 0    0  Gorilla_gorilla_gorilla       chr21   6586419
# 1    0             Homo_sapiens       chr21  19999946
# 2    0             Pan_paniscus  CM003404.1  20071554
# 3    0             Pongo_abelii  CM009283.2   7175441
# 0    1  Gorilla_gorilla_gorilla       chr21   6590887
# 1    1             Homo_sapiens       chr21  20004414
# 2    1             Pan_paniscus  CM003404.1  20076022
# 3    1             Pongo_abelii  CM009283.2   7179789
# 0    2  Gorilla_gorilla_gorilla       chr21   6595123
# 1    2             Homo_sapiens       chr21  20008672
# 2    2             Pan_paniscus  CM003404.1  20080282
# 3    2             Pongo_abelii  CM009283.2   7184043
# 0    3  Gorilla_gorilla_gorilla       chr21   6597056
# 1    3             Homo_sapiens       chr21  20010607
# 2    3             Pan_paniscus  CM003404.1  20081983
# 3    3             Pongo_abelii  CM009283.2   7185990
# 0    4  Gorilla_gorilla_gorilla       chr21   6599046
# 1    4             Homo_sapiens       chr21  20012587
# 2    4             Pan_paniscus  CM003404.1  20083941
# 3    4             Pongo_abelii  CM009283.2   7187978
# 0    5  Gorilla_gorilla_gorilla       chr21   6603148
# 1    5             Homo_sapiens       chr21  20016692
# 2    5             Pan_paniscus  CM003404.1  20088064
# 3    5             Pongo_abelii  CM009283.2   7192081
# 0    6  Gorilla_gorilla_gorilla       chr21   6605912
# 1    6             Homo_sapiens       chr21  20019467
# 2    6             Pan_paniscus  CM003404.1  20090829
# 3    6             Pongo_abelii  CM009283.2   7194868
# 0    7  Gorilla_gorilla_gorilla       chr21   6607854
# 1    7             Homo_sapiens       chr21  20021414
# 2    7             Pan_paniscus  CM003404.1  20092772
# 3    7             Pongo_abelii  CM009283.2   7196803
# 0    8  Gorilla_gorilla_gorilla       chr21   6611843
# 1    8             Homo_sapiens       chr21  20025428
# 2    8             Pan_paniscus  CM003404.1  20096787
# 3    8             Pongo_abelii  CM009283.2   7200814
# 0    9  Gorilla_gorilla_gorilla       chr21   6614699
# 1    9             Homo_sapiens       chr21  20028237
# 2    9             Pan_paniscus  CM003404.1  20099527
# 3    9             Pongo_abelii  CM009283.2   7203288
# 0   10  Gorilla_gorilla_gorilla       chr21   6616765
# 1   10             Homo_sapiens       chr21  20030302
# 2   10             Pan_paniscus  CM003404.1  20101590
# 3   10             Pongo_abelii  CM009283.2   7205350
# 0   11  Gorilla_gorilla_gorilla       chr21   6620251
# 1   11             Homo_sapiens       chr21  20033796
# 2   11             Pan_paniscus  CM003404.1  20105073
# 3   11             Pongo_abelii  CM009283.2   7208823
# 0   12  Gorilla_gorilla_gorilla       chr21   6621750
# 1   12             Homo_sapiens       chr21  20035307
# 2   12             Pan_paniscus  CM003404.1  20106582
# 3   12             Pongo_abelii  CM009283.2   7210278
# 0   13  Gorilla_gorilla_gorilla       chr21   6624950
# 1   13             Homo_sapiens       chr21  20038516
# 2   13             Pan_paniscus  CM003404.1  20110104
# 3   13             Pongo_abelii  CM009283.2   7213448
# 0   14  Gorilla_gorilla_gorilla       chr21   6629964
# 1   14             Homo_sapiens       chr21  20043536
# 2   14             Pan_paniscus  CM003404.1  20115119
# 3   14             Pongo_abelii  CM009283.2   7218442
#
#                                                 gaps
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1100000000000000000000111111111111111111111111...
# 1  1100000000000000000000111111111111111111111111...
# 2  0111111111111111111111111111111111111111111111...
# 3  1100000000000000000000111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111001111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111000111111111111111111111111001111...
# 3  1111111111111111111111111111111111111111001111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...

# %% [markdown]
# And as a sanity check we can also save the end coordinates from the alignment and the end coordinates calculated by summing the binary vector of gaps to the start coordinates.

# %%
dct2 = {}
results = idx.search([20000000], [20050000])

for i, align in enumerate(results):
    dct2[i] = {'end':[], 'end2':[]}
    AlignIO.write(align, '../results/small_subset/individual_alignments/chr21_subset{}.fa'.format(i), "fasta")
    for record in align:  
        dct2[i]['end'].append(record.annotations['start']+record.annotations['size'])
        dct2[i]['end2'].append(record.annotations['start']+sum([0 if n=='-' else 1 for n in record.seq]))

for i in dct2:
    print(dct2[i]['end'] == dct2[i]['end2'])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
