# %%
from Bio import Phylo
import matplotlib
from io import StringIO
from Bio.Phylo import PhyloXMLIO
import pandas as pd
import random
import os
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
from statistics import *

# %% [markdown]
# We can parse a newick string into the Phylo package:

# %%
newick = "(Phascolarctos_cinereus:158.59758758,(((Felis_catus:54.32144118,Canis_familiaris:54.32144118)'14':23.43351523,Sus_scrofa:77.75495641)'13':18.70743276,((Oryctolagus_cuniculus:82.14079889,Mus_musculus:82.14079889)'11':7.68238853,(((((Loris_tardigradus:26.22081462,(Nycticebus_pygmaeus:9.88809857,Nycticebus_bengalensis:9.88809857)'10':16.33271604)'19':11.56667300,(Otolemur_garnettii:18.60000000,Galago_moholi:18.60000000)'9':19.18748762)'22':21.53688150,(Daubentonia_madagascariensis:54.69862455,(Microcebus_murinus:38.36398632,(Prolemur_simus:13.74576625,Lemur_catta:13.74576625)'8':24.61822007)'6':16.33463823)'30':4.62574457)'29':14.51252523,((Pithecia_pithecia:21.87953444,((((Saguinus_midas:13.90999714,Callithrix_jacchus:13.90999714)'27':4.47385933,Aotus_nancymaae:18.38385647)'35':1.29720005,(Cebus_albifrons:5.67011500,Sapajus_apella:5.67011500)'43':14.01094152)'42':0.98253988,Ateles_fusciceps:20.66359640)'40':1.21593804)'48':21.27176190,(((((((Mandrillus_leucophaeus:2.03052000,Mandrillus_sphinx:2.03052000)'51':2.55985182,Cercocebus_atys:4.59037182)'47':7.80962818,(((Papio_hamadryas:1.73232857,Papio_anubis:1.73232857)'39':3.34795932,Theropithecus_gelada:5.08028789)'56':2.31985161,Lophocebus_aterrimus:7.40013950)'55':4.99986050)'61':0.00000000,((Macaca_mulatta:4.52740556,Macaca_assamensis:4.52740556)'60':0.75075744,(Macaca_silenus:2.28825400,Macaca_nemestrina:2.28825400)'54':2.98990900)'38':7.12183700)'34':1.34957083,((Erythrocebus_patas:5.88566500,(Chlorocebus_aethiops:3.42198857,Chlorocebus_sabaeus:3.42198857)'26':2.46367643)'66':6.47181833,(Cercopithecus_mitis:11.07659625,Cercopithecus_mona:11.07659625)'75':1.28088708)'80':1.39208750)'78':5.67273395,((((Rhinopithecus_roxellana:2.67843333,Rhinopithecus_strykeri:2.67843333)'74':4.48288394,Pygathrix_nemaeus:7.16131727)'83':2.95169085,Trachypithecus_phayrei:10.11300813)'73':3.90968949,(Piliocolobus_tephrosceles:12.80000000,(Colobus_angolensis_palliatus:3.17071750,Colobus_guereza:3.17071750)'88':9.62928250)'86':1.22269762)'72':5.39960716)'93':10.01924203,(((((Hylobates_pileatus:4.71177443,Hylobates_lar:4.71177443)'92':3.41722770,Symphalangus_syndactylus:8.12900213)'91':1.42887930,Hoolock_hoolock:9.55788143)'71':0.71776000,Nomascus_leucogenys:10.27564143)'69':9.91357211,((Gorilla_gorilla_gorilla:9.06309552,((Pan_troglodytes:2.82005943,Pan_paniscus:2.82005943)'65':3.83084557,Homo_sapiens:6.65090500)'25':2.41219052)'5':6.69907002,(Pongo_abelii:4.80376375,Pongo_pygmaeus:4.80376375)'102':10.95840179)'100':4.42704801)'107':9.25233327)'111':13.70974953)'110':30.68559800)'106':8.26531274,tree_shrew:82.10220708)'129':7.72098034)'128':6.63920175)'133':62.13519841);"

# %%
tree = Phylo.read(StringIO(newick), 'newick')

# %% [markdown]
# The tree looks like this:

# %%
Phylo.draw_ascii(tree)
# Out:
#   ___________________________________________ Phascolarctos_cinereus
#  |
#  |                             ______________ Felis_catus
#  |                      ______|
#  |                 ____|      |______________ Canis_familiaris
#  |                |    |
#  |                |    |_____________________ Sus_scrofa
#  |                |
#  |                |    ______________________ Oryctolagus_cuniculus
#  |                |  _|
#  |                | | |______________________ Mus_musculus
# _|                | |
#  |                | |                  ______ Loris_tardigradus
#  |                | |               __|
#  |                | |              |  |     _ Nycticebus_pygmaeus
#  |                | |              |  |____|
#  |                | |         _____|       |_ Nycticebus_bengalensis
#  |                | |        |     |
#  |                | |        |     |     ____ Otolemur_garnettii
#  |                | |     ___|     |____|
#  |                | |    |   |          |____ Galago_moholi
#  |                | |    |   |
#  |                | |    |   | ______________ Daubentonia_madagascariensis
#  |________________| |    |   ||
#                   | |    |    |     _________ Microcebus_murinus
#                   | |    |    |____|
#                   | |    |         |       __ Prolemur_simus
#                   | |    |         |______|
#                   | |    |                |__ Lemur_catta
#                   | |    |
#                   | |    |              _____ Pithecia_pithecia
#                   | |    |             |
#                   | |    |             |   __ Saguinus_midas
#                   | |    |             | _|
#                   | |    |        _____|| |__ Callithrix_jacchus
#                   | |    |       |     ||
#                   | |    |       |     ||____ Aotus_nancymaae
#                   | |    |       |     ||
#                   | |    |       |     ||   , Cebus_albifrons
#                   | |  __|       |     ||___|
#                   | | |  |       |      |   | Sapajus_apella
#                   | | |  |       |      |
#                   |_| |  |       |      |____ Ateles_fusciceps
#                     | |  |       |
#                     | |  |       |           , Mandrillus_leucophaeus
#                     | |  |       |          ,|
#                     | |  |       |         _|| Mandrillus_sphinx
#                     | |  |       |        | |
#                     | |  |       |        | | Cercocebus_atys
#                     | |  |       |        |
#                     | |  |       |        |  , Papio_hamadryas
#                     | |  |       |        | ,|
#                     | |  |       |        |,|| Papio_anubis
#                     | |  |       |        |||
#                     | |  |       |        ||| Theropithecus_gelada
#                     | |  |       |        ||
#                     | |  |       |        ||_ Lophocebus_aterrimus
#                     | |  |       |        |
#                     | |  |       |        | , Macaca_mulatta
#                     | |  |       |        | |
#                     | |  |_______|        | | Macaca_assamensis
#                     | |          |        |_|
#                     | |          |       _| |, Macaca_silenus
#                     | |          |      | | ||
#                     | |          |      | |  | Macaca_nemestrina
#                     | |          |      | |
#                     | |          |      | | , Erythrocebus_patas
#                     | |          |      | |_|
#                     | |          |      | | |, Chlorocebus_aethiops
#                     | |          |      | | ||
#                     | |          |      | |  | Chlorocebus_sabaeus
#                     | |          |      | |
#                     | |          |    __| |__ Cercopithecus_mitis
#                     | |          |   |  | |
#                     | |          |   |  | |__ Cercopithecus_mona
#                     |_|          |   |  |
#                       |          |   |  |    , Rhinopithecus_roxellana
#                       |          |   |  |   _|
#                       |          |   |  |  | | Rhinopithecus_strykeri
#                       |          |   |  |  |
#                       |          |   |  | ,|_ Pygathrix_nemaeus
#                       |          |   |  | ||
#                       |          |   |  |_||_ Trachypithecus_phayrei
#                       |          |   |    |
#                       |          |   |    |__ Piliocolobus_tephrosceles
#                       |          |   |    |
#                       |          |___|    |  , Colobus_angolensis_palliatus
#                       |              |    |__|
#                       |              |       | Colobus_guereza
#                       |              |
#                       |              |      , Hylobates_pileatus
#                       |              |     ,|
#                       |              |     || Hylobates_lar
#                       |              |     |
#                       |              |     |_ Symphalangus_syndactylus
#                       |              |     |
#                       |              |   __|_ Hoolock_hoolock
#                       |              |  |  |
#                       |              |  |  |_ Nomascus_leucogenys
#                       |              |  |
#                       |              |__|   _ Gorilla_gorilla_gorilla
#                       |                 |  |
#                       |                 | _| , Pan_troglodytes
#                       |                 || |,|
#                       |                 || ||| Pan_paniscus
#                       |                 ||  |
#                       |                  |  | Homo_sapiens
#                       |                  |
#                       |                  |  , Pongo_abelii
#                       |                  |__|
#                       |                     | Pongo_pygmaeus
#                       |
#                       |______________________ tree_shrew

# %% [markdown]
# The idea is converting the newick format into the phyloXML format in order to save more information for each of the clades. In fact, the attribute `other` for each clade can be used to store non-standard information. The `order.tag` attribute can store a string. When analizyng a non-terminal branch, we would like each node to contain information about:
# * best-quality terminal nodes for each of the two children clade.
# * best-quality terminal nodes for the sister clade.
# * closest outgroup / best-quality outgroup.
# The names of the species will be encoded in the following format: `children1 children2 sister outgroup`, so that it can directly be supplied to the maffilter pipeline.

# %% [markdown]
# The first step is to convert the newick-formatted tree into phyloxml:

# %%
Phylo.convert(StringIO(newick), 'newick', '../results/tree.xml', 'phyloxml')
# Out:
# 1

# %% [markdown]
# We are now able to read the saved XML tree:

# %%
tree = PhyloXMLIO.read('../results/tree.xml')[0]

# %% [markdown]
# Now we need a measure for the quality of each of the sequences. We will use the average contig length of the FASTA files as a proxy for quality. We can extract this information in the form of a dictionary:

# %%
contig = pd.read_csv('../data/contig_stats.txt', delim_whitespace = True)
contig['file'] = [i.split('.')[0] for i in contig['file']]
contig['avg_len'] = [float(i.replace(',','')) for i in contig['avg_len']]
contig = pd.Series(contig.avg_len.values,index=contig.file).to_dict()
contig
# Out:
# {'Aotus_nancymaae': 98947.8,
#  'Ateles_fusciceps': 985320.9,
#  'Callithrix_jacchus': 2613015.2,
#  'Canis_familiaris': 737753.0,
#  'Cebus_albifrons': 1382608.1,
#  'Cercocebus_atys': 249125.0,
#  'Cercopithecus_mitis': 782155.3,
#  'Cercopithecus_mona': 1536688.6,
#  'Chlorocebus_aethiops': 1100250.9,
#  'Chlorocebus_sabaeus': 1392730.8,
#  'Colobus_angolensis_palliatus': 226312.5,
#  'Colobus_guereza': 128847939.3,
#  'Daubentonia_madagascariensis': 890714.9,
#  'Erythrocebus_patas': 632284.5,
#  'Felis_catus': 559419.7,
#  'Galago_moholi': 213775.0,
#  'Gorilla_gorilla_gorilla': 201647.1,
#  'Homo_sapiens': 15978096.5,
#  'Hoolock_hoolock': 937112.7,
#  'Hylobates_lar': 123977325.3,
#  'Hylobates_pileatus': 1212956.4,
#  'Lemur_catta': 15052140.1,
#  'Lophocebus_aterrimus': 661506.4,
#  'Loris_tardigradus': 763450.9,
#  'Macaca_arctoides': 2449573.7,
#  'Macaca_assamensis': 2393214.2,
#  'Macaca_fascicularis': 1185158.3,
#  'Macaca_fuscata': 2260264.1,
#  'Macaca_leonina': 963596.0,
#  'Macaca_mulatta': 134340482.0,
#  'Macaca_nemestrina': 302959.4,
#  'Macaca_nigra': 92612.5,
#  'Macaca_silenus': 1536092.7,
#  'Macaca_sylvanus': 85790.9,
#  'Macaca_thibetana': 1691140.1,
#  'Macaca_tonkeana': 63079.4,
#  'Mandrillus_leucophaeus': 81802.5,
#  'Mandrillus_sphinx': 1339162.4,
#  'Microcebus_murinus': 324005.7,
#  'Mus_musculus': 41376845.1,
#  'Nomascus_leucogenys': 1050625.5,
#  'Nycticebus_bengalensis': 842338.2,
#  'Nycticebus_pygmaeus': 595020.4,
#  'Ornithorhynchus_anatinus': 2709550.9,
#  'Oryctolagus_cuniculus': 844383.3,
#  'Otolemur_garnettii': 323331.8,
#  'Pan_paniscus': 319899.2,
#  'Pan_troglodytes': 696139.7,
#  'Papio_anubis': 46800.1,
#  'Papio_hamadryas': 1002407.4,
#  'Phascolarctos_cinereus': 1674138.2,
#  'Piliocolobus_tephrosceles': 64026.8,
#  'Pithecia_pithecia': 2001058.6,
#  'Pongo_abelii': 582706.4,
#  'Pongo_pygmaeus': 832422.2,
#  'Prolemur_simus': 18753.3,
#  'Pygathrix_nemaeus': 771499.8,
#  'Rhinopithecus_roxellana': 933188.1,
#  'Rhinopithecus_strykeri': 634426.4,
#  'Saguinus_midas': 123696349.1,
#  'Sapajus_apella': 660559.9,
#  'Sus_scrofa': 4081423.1,
#  'Symphalangus_syndactylus': 1968807.7,
#  'Theropithecus_gelada': 188777.3,
#  'Trachypithecus_phayrei': 974473.8,
#  'tree_shrew': 1619615.8}

# %% [markdown]
# We can define all the functions for tagging a tree.

# %%
def get_best(clade):
    """
    This function returns the name of the best-quality
    terminal node for a certain clade.
    """
    # Define the accumulator of the score
    num = 0
    # For each of the clade terminal nodes
    for i in clade.get_terminals():
        # If the score is larger than the maximum
        if i.other.tag > num:
            # Save the new maximum
            num = i.other.tag
            # Save the name of the terminal node
            best = i.name
    return best

def proxy_clades(clade):
    """
    This function returns a PhyloXML.Other object with
    the best-scoring terminal nodes for each of the 
    children branches of a certain clade.
    """
    left = get_best(clade.clades[0])
    right = get_best(clade.clades[1])
    # Sort the two best-scoring nodes alphabetically
    lst = [left, right]
    lst.sort()
    # Return them as a PhyloXML.Other object
    return Phylo.PhyloXML.Other(tag=lst[0]+' '+lst[1])


def get_parent(tree, child_clade):
    """
    Function for getting the pointer to the parent clade.
    If the clade has no parents (this is, the root), then
    None is returned. 
    """
    node_path = tree.get_path(child_clade)
    if len(node_path)>1:
        return node_path[-2]
    else:
        return None
    
def get_sister(tree, child_clade):
    """
    Function for getting the pointer to the sister clase.
    """
    return [i for i in get_parent(tree, child_clade).clades if i != child_clade][0]



def tag_tree(tree):
    
    """
    This function returns a tree for which all internal branches
    are tagged with a PhyloXML.Other attribute, whose tag argument
    is a string that contains the following:
        The best-scoring species from the left child clade.
        The best-scoring species from the right child clade.
        The best-scoring species from the sister clade.
        The best-scoring outgroup.
    
    Moreover, the returned tree is also tagged with the quality 
    score for all the terminal nodes. 
    """
    
    # TAG ALL TERMINAL NODES WITH QUALITY PROXY
    # For each terminal node
    for clade in tree.get_terminals():
        # Look up the quality score and save it in clade.other
        clade.other = Phylo.PhyloXML.Other(tag=contig[clade.name])

    # BEST-SCORING SPECIES IN CHILDREN CLADES
    # For each non-terminal node
    for clade in tree.get_nonterminals():
        # Look up best-scoring species of the two children clades
        clade.other = proxy_clades(clade)

    # BEST-SCORING SPECIES IN SISTER CLADE
    # For each non-terminal node
    for clade in tree.get_nonterminals():
        # If the clade has a parent
        if get_parent(tree, clade) is not None:
            # Find best-scoring species in sister clade
            clade.other.tag = clade.other.tag+' '+get_best(get_sister(tree, clade))

    # BEST-SCORING OUTGROUP
    # For each non-terminal clade
    for clade in tree.get_nonterminals():
        # If the clade has a parent
        if get_parent(tree, clade) is not None:
            # If the parent clade has a parent
            if get_parent(tree, get_parent(tree, clade)) is not None:
                # Find best-scoring speices
                clade.other.tag = clade.other.tag+' '+get_best(get_sister(tree, get_parent(tree, clade)))
            
    # Print all combinations of species that should be sent to cluster        
    print([clade.other.tag for clade in tree.get_nonterminals() if len(clade.other.tag.split(' '))==4])
    
    return tree

# %%
# Load the tree
tree = PhyloXMLIO.read('../results/tree.xml')[0]

tree = tag_tree(tree)

tree.ladderize()

# Phylo.write(tree, 'tree_proxy.xml', 'phyloxml')
# Out:
# ['Canis_familiaris Felis_catus Sus_scrofa Macaca_mulatta', 'Mus_musculus Oryctolagus_cuniculus Macaca_mulatta Sus_scrofa', 'Macaca_mulatta tree_shrew Mus_musculus Sus_scrofa', 'Lemur_catta Macaca_mulatta tree_shrew Mus_musculus', 'Lemur_catta Nycticebus_bengalensis Macaca_mulatta tree_shrew', 'Nycticebus_bengalensis Otolemur_garnettii Lemur_catta Macaca_mulatta', 'Loris_tardigradus Nycticebus_bengalensis Otolemur_garnettii Lemur_catta', 'Nycticebus_bengalensis Nycticebus_pygmaeus Loris_tardigradus Otolemur_garnettii', 'Galago_moholi Otolemur_garnettii Nycticebus_bengalensis Lemur_catta', 'Daubentonia_madagascariensis Lemur_catta Nycticebus_bengalensis Macaca_mulatta', 'Lemur_catta Microcebus_murinus Daubentonia_madagascariensis Nycticebus_bengalensis', 'Lemur_catta Prolemur_simus Microcebus_murinus Daubentonia_madagascariensis', 'Macaca_mulatta Saguinus_midas Lemur_catta tree_shrew', 'Pithecia_pithecia Saguinus_midas Macaca_mulatta Lemur_catta', 'Ateles_fusciceps Saguinus_midas Pithecia_pithecia Macaca_mulatta', 'Cebus_albifrons Saguinus_midas Ateles_fusciceps Pithecia_pithecia', 'Aotus_nancymaae Saguinus_midas Cebus_albifrons Ateles_fusciceps', 'Callithrix_jacchus Saguinus_midas Aotus_nancymaae Cebus_albifrons', 'Cebus_albifrons Sapajus_apella Saguinus_midas Ateles_fusciceps', 'Hylobates_lar Macaca_mulatta Saguinus_midas Lemur_catta', 'Colobus_guereza Macaca_mulatta Hylobates_lar Saguinus_midas', 'Cercopithecus_mona Macaca_mulatta Colobus_guereza Hylobates_lar', 'Macaca_mulatta Mandrillus_sphinx Cercopithecus_mona Colobus_guereza', 'Mandrillus_sphinx Papio_hamadryas Macaca_mulatta Cercopithecus_mona', 'Cercocebus_atys Mandrillus_sphinx Papio_hamadryas Macaca_mulatta', 'Mandrillus_leucophaeus Mandrillus_sphinx Cercocebus_atys Papio_hamadryas', 'Lophocebus_aterrimus Papio_hamadryas Mandrillus_sphinx Macaca_mulatta', 'Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus Mandrillus_sphinx', 'Papio_anubis Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus', 'Macaca_mulatta Macaca_silenus Mandrillus_sphinx Cercopithecus_mona', 'Macaca_assamensis Macaca_mulatta Macaca_silenus Mandrillus_sphinx', 'Macaca_nemestrina Macaca_silenus Macaca_mulatta Mandrillus_sphinx', 'Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta Colobus_guereza', 'Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona Macaca_mulatta', 'Chlorocebus_aethiops Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona', 'Cercopithecus_mitis Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta', 'Colobus_guereza Trachypithecus_phayrei Macaca_mulatta Hylobates_lar', 'Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza Macaca_mulatta', 'Pygathrix_nemaeus Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza', 'Rhinopithecus_roxellana Rhinopithecus_strykeri Pygathrix_nemaeus Trachypithecus_phayrei', 'Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei Macaca_mulatta', 'Colobus_angolensis_palliatus Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei', 'Homo_sapiens Hylobates_lar Macaca_mulatta Saguinus_midas', 'Hylobates_lar Nomascus_leucogenys Homo_sapiens Macaca_mulatta', 'Hoolock_hoolock Hylobates_lar Nomascus_leucogenys Homo_sapiens', 'Hylobates_lar Symphalangus_syndactylus Hoolock_hoolock Nomascus_leucogenys', 'Hylobates_lar Hylobates_pileatus Symphalangus_syndactylus Hoolock_hoolock', 'Homo_sapiens Pongo_pygmaeus Hylobates_lar Macaca_mulatta', 'Gorilla_gorilla_gorilla Homo_sapiens Pongo_pygmaeus Hylobates_lar', 'Homo_sapiens Pan_troglodytes Gorilla_gorilla_gorilla Pongo_pygmaeus', 'Pan_paniscus Pan_troglodytes Homo_sapiens Gorilla_gorilla_gorilla', 'Pongo_abelii Pongo_pygmaeus Homo_sapiens Hylobates_lar']

# %% [markdown]
# For saving the information about the quality we can ge the terminal nodes and save the number associated with it by consulting it on the dictionary. We can extract the ILS and asymmetry scores for the autosomes and the X chromosome. For the calculation of the most common alternative topology, the Y chromosome was left out because when the proportion of ILS was very small the contribution of the Y chromosome could influence it (as is the case of Rhinopithecus_roxellana Rhinopithecus_strykeri Pygathrix_nemaeus Trachypithecus_phayrei).

# %%
dct = {}


for name in os.listdir('../data/each_branch/'):
    
    # Read the csv file
    df = pd.read_csv('../data/each_branch/'+name)
    # Rename the chromosome column
    df.rename(columns={df.columns[0]: "chr",
                       df.columns[1]: '.'.join(df.columns[1].split(',')),
                       df.columns[2]: '.'.join(df.columns[2].split(',')), 
                       df.columns[3]: '.'.join(df.columns[3].split(','))}, inplace = True)
    # Extract chromosome name
    df['chr'] = [i.split('.')[0] for i in df['chr']]
    # Define the levels of the chromosomes
    cat_type = CategoricalDtype(categories=['chr'+str(i) for i in range(1, 23)]+['chrX', 'chrY'], ordered=True)
    # Assign levels to column
    df['chr'] = df['chr'].astype(cat_type)
    # Sort the chromosomes
    df.sort_values(by=['chr'], inplace=True)

    # Sum all rows without the Y chromosome
    summary = pd.DataFrame(df.iloc[:-1,1:].sum(axis=0))
    # Sort the number of trees in descending order
    summary.sort_values(by=0, inplace=True, ascending=False)
    # Convert the row names to a list
    canonical = list(summary.index.values)
    # Add the chromosomes to the ordered list
    canonical.append('chr')
    # Select columns in the right order: canonical, most-common alternative, least-common alternative
    df = df[canonical]
    # Calculate overall ILS
    df['ILS'] = (df[canonical[1]]+df[canonical[2]])/(df[canonical[0]]+df[canonical[1]]+df[canonical[2]])
    # Calculate the asymmetry index
    df['asymmetry'] = df[canonical[1]]/df[canonical[2]]

    # Save autosomal and sex chromosomal ILS and symmetry index to dictionary
    dct[name[:-4].replace('.', ' ')]={'A_ILS' : round((sum(df[canonical[1]].iloc[0:21])+sum(df[canonical[2]].iloc[0:21]))/(sum(df[canonical[0]].iloc[0:21])+sum(df[canonical[1]].iloc[0:21])+sum(df[canonical[2]].iloc[0:21])), 4),
                                 'X_ILS' : round((df[canonical[1]].iloc[22]+df[canonical[2]].iloc[22])/(df[canonical[0]].iloc[22]+df[canonical[1]].iloc[22]+df[canonical[2]].iloc[22]), 4),
                                 'A_sim' : round(sum(df[canonical[1]].iloc[0:21])/sum(df[canonical[2]].iloc[0:21]), 4),
                                 'X_sim' : round(df[canonical[1]].iloc[22]/df[canonical[2]].iloc[22], 4)}

    # Save csv file
    df.to_csv('../results/each_branch/{}.csv'.format('.'.join(name.split('.')[:-1])), index=False)

# %%
dct
# Out:
# {'Pygathrix_nemaeus Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza': {'A_ILS': 0.375,
#   'X_ILS': 0.3333,
#   'A_sim': 1.0512,
#   'X_sim': 1.0898},
#  'Gorilla_gorilla_gorilla Homo_sapiens Pongo_pygmaeus Hylobates_lar': {'A_ILS': 0.0132,
#   'X_ILS': 0.0178,
#   'A_sim': 1.0273,
#   'X_sim': 1.1162},
#  'Chlorocebus_aethiops Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona': {'A_ILS': 0.1656,
#   'X_ILS': 0.1694,
#   'A_sim': 1.0226,
#   'X_sim': 1.0364},
#  'Mandrillus_sphinx Papio_hamadryas Macaca_mulatta Cercopithecus_mona': {'A_ILS': 0.4177,
#   'X_ILS': 0.4271,
#   'A_sim': 1.0322,
#   'X_sim': 1.1242},
#  'Pongo_abelii Pongo_pygmaeus Homo_sapiens Hylobates_lar': {'A_ILS': 0.0029,
#   'X_ILS': 0.0029,
#   'A_sim': 1.5623,
#   'X_sim': 1.5773},
#  'Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei Macaca_mulatta': {'A_ILS': 0.3191,
#   'X_ILS': 0.2009,
#   'A_sim': 1.0099,
#   'X_sim': 1.1154},
#  'Lemur_catta Prolemur_simus Microcebus_murinus Daubentonia_madagascariensis': {'A_ILS': 0.0012,
#   'X_ILS': 0.0024,
#   'A_sim': 1.0429,
#   'X_sim': 1.2692},
#  'Cercopithecus_mitis Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta': {'A_ILS': 0.2228,
#   'X_ILS': 0.2138,
#   'A_sim': 1.0036,
#   'X_sim': 1.021},
#  'Cercopithecus_mona Macaca_mulatta Colobus_guereza Hylobates_lar': {'A_ILS': 0.1447,
#   'X_ILS': 0.0846,
#   'A_sim': 1.0174,
#   'X_sim': 1.083},
#  'Papio_anubis Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus': {'A_ILS': 0.2464,
#   'X_ILS': 0.2435,
#   'A_sim': 1.0081,
#   'X_sim': 1.0642},
#  'Cebus_albifrons Sapajus_apella Saguinus_midas Ateles_fusciceps': {'A_ILS': 0.0018,
#   'X_ILS': 0.0073,
#   'A_sim': 0.9642,
#   'X_sim': 1.7795},
#  'Colobus_angolensis_palliatus Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei': {'A_ILS': 0.0235,
#   'X_ILS': 0.0382,
#   'A_sim': 1.0989,
#   'X_sim': 1.4828},
#  'Pan_paniscus Pan_troglodytes Homo_sapiens Gorilla_gorilla_gorilla': {'A_ILS': 0.0793,
#   'X_ILS': 0.0801,
#   'A_sim': 1.0394,
#   'X_sim': 1.0089},
#  'Lemur_catta Macaca_mulatta tree_shrew Mus_musculus': {'A_ILS': 0.418,
#   'X_ILS': 0.3888,
#   'A_sim': 2.1315,
#   'X_sim': 2.0325},
#  'Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus Mandrillus_sphinx': {'A_ILS': 0.5969,
#   'X_ILS': 0.5761,
#   'A_sim': 1.0678,
#   'X_sim': 1.0433},
#  'Cercocebus_atys Mandrillus_sphinx Papio_hamadryas Macaca_mulatta': {'A_ILS': 0.517,
#   'X_ILS': 0.498,
#   'A_sim': 1.0149,
#   'X_sim': 1.088},
#  'Lemur_catta Microcebus_murinus Daubentonia_madagascariensis Nycticebus_bengalensis': {'A_ILS': 0.0092,
#   'X_ILS': 0.0091,
#   'A_sim': 1.3013,
#   'X_sim': 1.6333},
#  'Hylobates_lar Symphalangus_syndactylus Hoolock_hoolock Nomascus_leucogenys': {'A_ILS': 0.6351,
#   'X_ILS': 0.643,
#   'A_sim': 1.0316,
#   'X_sim': 1.0507},
#  'Macaca_mulatta tree_shrew Mus_musculus Sus_scrofa': {'A_ILS': 0.581,
#   'X_ILS': 0.5892,
#   'A_sim': 1.225,
#   'X_sim': 1.0435},
#  'Lophocebus_aterrimus Papio_hamadryas Mandrillus_sphinx Macaca_mulatta': {'A_ILS': 0.2314,
#   'X_ILS': 0.214,
#   'A_sim': 1.027,
#   'X_sim': 1.0743},
#  'Daubentonia_madagascariensis Lemur_catta Nycticebus_bengalensis Macaca_mulatta': {'A_ILS': 0.2738,
#   'X_ILS': 0.28,
#   'A_sim': 1.0833,
#   'X_sim': 1.0984},
#  'Macaca_assamensis Macaca_mulatta Macaca_silenus Mandrillus_sphinx': {'A_ILS': 0.6264,
#   'X_ILS': 0.662,
#   'A_sim': 1.235,
#   'X_sim': 1.0995},
#  'Aotus_nancymaae Saguinus_midas Cebus_albifrons Ateles_fusciceps': {'A_ILS': 0.6504,
#   'X_ILS': 0.655,
#   'A_sim': 1.029,
#   'X_sim': 1.0101},
#  'Pithecia_pithecia Saguinus_midas Macaca_mulatta Lemur_catta': {'A_ILS': 0.0014,
#   'X_ILS': 0.0029,
#   'A_sim': 1.4813,
#   'X_sim': 2.0952},
#  'Hylobates_lar Macaca_mulatta Saguinus_midas Lemur_catta': {'A_ILS': 0.0337,
#   'X_ILS': 0.0253,
#   'A_sim': 1.1202,
#   'X_sim': 0.957},
#  'Callithrix_jacchus Saguinus_midas Aotus_nancymaae Cebus_albifrons': {'A_ILS': 0.0167,
#   'X_ILS': 0.016,
#   'A_sim': 1.0328,
#   'X_sim': 1.3806},
#  'Macaca_nemestrina Macaca_silenus Macaca_mulatta Mandrillus_sphinx': {'A_ILS': 0.3679,
#   'X_ILS': 0.3217,
#   'A_sim': 1.0675,
#   'X_sim': 0.9837},
#  'Mus_musculus Oryctolagus_cuniculus Macaca_mulatta Sus_scrofa': {'A_ILS': 0.6214,
#   'X_ILS': 0.6266,
#   'A_sim': 1.5011,
#   'X_sim': 1.4655},
#  'Galago_moholi Otolemur_garnettii Nycticebus_bengalensis Lemur_catta': {'A_ILS': nan,
#   'X_ILS': 0.0055,
#   'A_sim': nan,
#   'X_sim': 1.871},
#  'Cebus_albifrons Saguinus_midas Ateles_fusciceps Pithecia_pithecia': {'A_ILS': 0.1997,
#   'X_ILS': 0.197,
#   'A_sim': 1.0163,
#   'X_sim': 0.9872},
#  'Canis_familiaris Felis_catus Sus_scrofa Macaca_mulatta': {'A_ILS': 0.0036,
#   'X_ILS': 0.0064,
#   'A_sim': 1.0378,
#   'X_sim': 0.7209},
#  'Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza Macaca_mulatta': {'A_ILS': 0.088,
#   'X_ILS': 0.1186,
#   'A_sim': 1.0008,
#   'X_sim': 0.9997},
#  'Homo_sapiens Pan_troglodytes Gorilla_gorilla_gorilla Pongo_pygmaeus': {'A_ILS': 0.3727,
#   'X_ILS': 0.2445,
#   'A_sim': 1.0105,
#   'X_sim': 1.0161},
#  'Macaca_mulatta Macaca_silenus Mandrillus_sphinx Cercopithecus_mona': {'A_ILS': 0.0742,
#   'X_ILS': 0.1321,
#   'A_sim': 1.0519,
#   'X_sim': 1.0095},
#  'Macaca_mulatta Saguinus_midas Lemur_catta tree_shrew': {'A_ILS': nan,
#   'X_ILS': 0.0016,
#   'A_sim': nan,
#   'X_sim': 3.25},
#  'Hylobates_lar Hylobates_pileatus Symphalangus_syndactylus Hoolock_hoolock': {'A_ILS': 0.0125,
#   'X_ILS': 0.0262,
#   'A_sim': 1.0752,
#   'X_sim': 0.9906},
#  'Mandrillus_leucophaeus Mandrillus_sphinx Cercocebus_atys Papio_hamadryas': {'A_ILS': 0.2044,
#   'X_ILS': 0.1074,
#   'A_sim': 1.036,
#   'X_sim': 1.0872},
#  'Nycticebus_bengalensis Nycticebus_pygmaeus Loris_tardigradus Otolemur_garnettii': {'A_ILS': 0.0022,
#   'X_ILS': 0.0037,
#   'A_sim': 1.0885,
#   'X_sim': 1.1935},
#  'Loris_tardigradus Nycticebus_bengalensis Otolemur_garnettii Lemur_catta': {'A_ILS': 0.0045,
#   'X_ILS': 0.0083,
#   'A_sim': 1.1269,
#   'X_sim': 1.0435},
#  'Colobus_guereza Macaca_mulatta Hylobates_lar Saguinus_midas': {'A_ILS': 0.0025,
#   'X_ILS': 0.0101,
#   'A_sim': 1.6215,
#   'X_sim': 3.0},
#  'Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta Colobus_guereza': {'A_ILS': 0.2259,
#   'X_ILS': 0.2246,
#   'A_sim': 1.0147,
#   'X_sim': 0.983},
#  'Hoolock_hoolock Hylobates_lar Nomascus_leucogenys Homo_sapiens': {'A_ILS': 0.6539,
#   'X_ILS': 0.6561,
#   'A_sim': 1.1093,
#   'X_sim': 1.1389},
#  'Ateles_fusciceps Saguinus_midas Pithecia_pithecia Macaca_mulatta': {'A_ILS': 0.5836,
#   'X_ILS': 0.5386,
#   'A_sim': 1.0199,
#   'X_sim': 1.2445},
#  'Lemur_catta Nycticebus_bengalensis Macaca_mulatta tree_shrew': {'A_ILS': 0.0131,
#   'X_ILS': 0.0141,
#   'A_sim': 1.3707,
#   'X_sim': 1.2667},
#  'Homo_sapiens Pongo_pygmaeus Hylobates_lar Macaca_mulatta': {'A_ILS': 0.3663,
#   'X_ILS': 0.3255,
#   'A_sim': 1.0108,
#   'X_sim': 1.0109},
#  'Hylobates_lar Nomascus_leucogenys Homo_sapiens Macaca_mulatta': {'A_ILS': 0.0042,
#   'X_ILS': 0.0142,
#   'A_sim': 1.4249,
#   'X_sim': 4.1282},
#  'Macaca_mulatta Mandrillus_sphinx Cercopithecus_mona Colobus_guereza': {'A_ILS': 0.2101,
#   'X_ILS': 0.1745,
#   'A_sim': 1.0072,
#   'X_sim': 0.9845},
#  'Rhinopithecus_roxellana Rhinopithecus_strykeri Pygathrix_nemaeus Trachypithecus_phayrei': {'A_ILS': 0.0724,
#   'X_ILS': 0.0868,
#   'A_sim': 1.0034,
#   'X_sim': 1.0508},
#  'Nycticebus_bengalensis Otolemur_garnettii Lemur_catta Macaca_mulatta': {'A_ILS': nan,
#   'X_ILS': 0.0023,
#   'A_sim': nan,
#   'X_sim': 0.6522},
#  'Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona Macaca_mulatta': {'A_ILS': 0.1511,
#   'X_ILS': 0.1493,
#   'A_sim': 1.0141,
#   'X_sim': 1.0508},
#  'Homo_sapiens Hylobates_lar Macaca_mulatta Saguinus_midas': {'A_ILS': 0.0415,
#   'X_ILS': 0.0369,
#   'A_sim': 1.0877,
#   'X_sim': 1.5952},
#  'Colobus_guereza Trachypithecus_phayrei Macaca_mulatta Hylobates_lar': {'A_ILS': 0.0824,
#   'X_ILS': 0.087,
#   'A_sim': 1.0649,
#   'X_sim': 1.6618}}

# %%
def extract_label(clade):
    """
    This function returns the autosomal and sex chromosomal 
    ILS and symmetry index of each clade for the plot. It
    rounds the scores to 4 digits. If the branch has no score
    None is returned instead. 
    """
    
    # If the quartet was sent to the cluster
    if (isinstance(clade.other.tag, str)) and (len(clade.other.tag.split(' ')) == 4):
        # Extract scores from dictionary and format the output
        tag = [str("%.4f" % dct[clade.other.tag][i]) for i in dct[clade.other.tag]]
        return tag[0]+' '+tag[1]+'\t '+tag[2]+' '+tag[3]
    
    else:
        return clade.name

# %%
tree2 = PhyloXMLIO.read('../results/tree.xml')[0]

tree2 = tag_tree(tree2)

tree2.ladderize()

for clade in tree2.find_clades():
    clade.name = extract_label(clade)

Phylo.write(tree2, '../results/tree.new', 'newick')
# Out:
# ['Canis_familiaris Felis_catus Sus_scrofa Macaca_mulatta', 'Mus_musculus Oryctolagus_cuniculus Macaca_mulatta Sus_scrofa', 'Macaca_mulatta tree_shrew Mus_musculus Sus_scrofa', 'Lemur_catta Macaca_mulatta tree_shrew Mus_musculus', 'Lemur_catta Nycticebus_bengalensis Macaca_mulatta tree_shrew', 'Nycticebus_bengalensis Otolemur_garnettii Lemur_catta Macaca_mulatta', 'Loris_tardigradus Nycticebus_bengalensis Otolemur_garnettii Lemur_catta', 'Nycticebus_bengalensis Nycticebus_pygmaeus Loris_tardigradus Otolemur_garnettii', 'Galago_moholi Otolemur_garnettii Nycticebus_bengalensis Lemur_catta', 'Daubentonia_madagascariensis Lemur_catta Nycticebus_bengalensis Macaca_mulatta', 'Lemur_catta Microcebus_murinus Daubentonia_madagascariensis Nycticebus_bengalensis', 'Lemur_catta Prolemur_simus Microcebus_murinus Daubentonia_madagascariensis', 'Macaca_mulatta Saguinus_midas Lemur_catta tree_shrew', 'Pithecia_pithecia Saguinus_midas Macaca_mulatta Lemur_catta', 'Ateles_fusciceps Saguinus_midas Pithecia_pithecia Macaca_mulatta', 'Cebus_albifrons Saguinus_midas Ateles_fusciceps Pithecia_pithecia', 'Aotus_nancymaae Saguinus_midas Cebus_albifrons Ateles_fusciceps', 'Callithrix_jacchus Saguinus_midas Aotus_nancymaae Cebus_albifrons', 'Cebus_albifrons Sapajus_apella Saguinus_midas Ateles_fusciceps', 'Hylobates_lar Macaca_mulatta Saguinus_midas Lemur_catta', 'Colobus_guereza Macaca_mulatta Hylobates_lar Saguinus_midas', 'Cercopithecus_mona Macaca_mulatta Colobus_guereza Hylobates_lar', 'Macaca_mulatta Mandrillus_sphinx Cercopithecus_mona Colobus_guereza', 'Mandrillus_sphinx Papio_hamadryas Macaca_mulatta Cercopithecus_mona', 'Cercocebus_atys Mandrillus_sphinx Papio_hamadryas Macaca_mulatta', 'Mandrillus_leucophaeus Mandrillus_sphinx Cercocebus_atys Papio_hamadryas', 'Lophocebus_aterrimus Papio_hamadryas Mandrillus_sphinx Macaca_mulatta', 'Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus Mandrillus_sphinx', 'Papio_anubis Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus', 'Macaca_mulatta Macaca_silenus Mandrillus_sphinx Cercopithecus_mona', 'Macaca_assamensis Macaca_mulatta Macaca_silenus Mandrillus_sphinx', 'Macaca_nemestrina Macaca_silenus Macaca_mulatta Mandrillus_sphinx', 'Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta Colobus_guereza', 'Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona Macaca_mulatta', 'Chlorocebus_aethiops Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona', 'Cercopithecus_mitis Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta', 'Colobus_guereza Trachypithecus_phayrei Macaca_mulatta Hylobates_lar', 'Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza Macaca_mulatta', 'Pygathrix_nemaeus Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza', 'Rhinopithecus_roxellana Rhinopithecus_strykeri Pygathrix_nemaeus Trachypithecus_phayrei', 'Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei Macaca_mulatta', 'Colobus_angolensis_palliatus Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei', 'Homo_sapiens Hylobates_lar Macaca_mulatta Saguinus_midas', 'Hylobates_lar Nomascus_leucogenys Homo_sapiens Macaca_mulatta', 'Hoolock_hoolock Hylobates_lar Nomascus_leucogenys Homo_sapiens', 'Hylobates_lar Symphalangus_syndactylus Hoolock_hoolock Nomascus_leucogenys', 'Hylobates_lar Hylobates_pileatus Symphalangus_syndactylus Hoolock_hoolock', 'Homo_sapiens Pongo_pygmaeus Hylobates_lar Macaca_mulatta', 'Gorilla_gorilla_gorilla Homo_sapiens Pongo_pygmaeus Hylobates_lar', 'Homo_sapiens Pan_troglodytes Gorilla_gorilla_gorilla Pongo_pygmaeus', 'Pan_paniscus Pan_troglodytes Homo_sapiens Gorilla_gorilla_gorilla', 'Pongo_abelii Pongo_pygmaeus Homo_sapiens Hylobates_lar']
# 1

# %%
fig= plt.figure(figsize=(70,130))
axes = fig.add_subplot(1, 1, 1)
matplotlib.rc('font', size=20)
Phylo.draw(tree, axes=axes, label_func=extract_label, show_confidence=False, do_show=False)
plt.savefig('../plots/line_plot.pdf', bbox_inches='tight')
# Out:
# /Users/au595587/opt/miniconda3/envs/primates/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /Users/au595587/opt/miniconda3/envs/primates/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:2001: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Users/au595587/opt/miniconda3/envs/primates/lib/python3.8/site-packages/matplotlib/backends/_backend_pdf_ps.py:62: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# /Users/au595587/opt/miniconda3/envs/primates/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:2001: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Users/au595587/opt/miniconda3/envs/primates/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/au595587/opt/miniconda3/envs/primates/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Load the tree
tree2 = PhyloXMLIO.read('../results/tree.xml')[0]

tree2 = tag_tree(tree2)

for clade in tree2.find_clades():
    clade.branch_length = 1
    
tree2.ladderize()

fig= plt.figure(figsize=(70,130))
axes = fig.add_subplot(1, 1, 1)
matplotlib.rc('font', size=20)
Phylo.draw(tree2, axes=axes, label_func=extract_label, show_confidence=False)
# Out:
# ['Canis_familiaris Felis_catus Sus_scrofa Macaca_mulatta', 'Mus_musculus Oryctolagus_cuniculus Macaca_mulatta Sus_scrofa', 'Macaca_mulatta tree_shrew Mus_musculus Sus_scrofa', 'Lemur_catta Macaca_mulatta tree_shrew Mus_musculus', 'Lemur_catta Nycticebus_bengalensis Macaca_mulatta tree_shrew', 'Nycticebus_bengalensis Otolemur_garnettii Lemur_catta Macaca_mulatta', 'Loris_tardigradus Nycticebus_bengalensis Otolemur_garnettii Lemur_catta', 'Nycticebus_bengalensis Nycticebus_pygmaeus Loris_tardigradus Otolemur_garnettii', 'Galago_moholi Otolemur_garnettii Nycticebus_bengalensis Lemur_catta', 'Daubentonia_madagascariensis Lemur_catta Nycticebus_bengalensis Macaca_mulatta', 'Lemur_catta Microcebus_murinus Daubentonia_madagascariensis Nycticebus_bengalensis', 'Lemur_catta Prolemur_simus Microcebus_murinus Daubentonia_madagascariensis', 'Macaca_mulatta Saguinus_midas Lemur_catta tree_shrew', 'Pithecia_pithecia Saguinus_midas Macaca_mulatta Lemur_catta', 'Ateles_fusciceps Saguinus_midas Pithecia_pithecia Macaca_mulatta', 'Cebus_albifrons Saguinus_midas Ateles_fusciceps Pithecia_pithecia', 'Aotus_nancymaae Saguinus_midas Cebus_albifrons Ateles_fusciceps', 'Callithrix_jacchus Saguinus_midas Aotus_nancymaae Cebus_albifrons', 'Cebus_albifrons Sapajus_apella Saguinus_midas Ateles_fusciceps', 'Hylobates_lar Macaca_mulatta Saguinus_midas Lemur_catta', 'Colobus_guereza Macaca_mulatta Hylobates_lar Saguinus_midas', 'Cercopithecus_mona Macaca_mulatta Colobus_guereza Hylobates_lar', 'Macaca_mulatta Mandrillus_sphinx Cercopithecus_mona Colobus_guereza', 'Mandrillus_sphinx Papio_hamadryas Macaca_mulatta Cercopithecus_mona', 'Cercocebus_atys Mandrillus_sphinx Papio_hamadryas Macaca_mulatta', 'Mandrillus_leucophaeus Mandrillus_sphinx Cercocebus_atys Papio_hamadryas', 'Lophocebus_aterrimus Papio_hamadryas Mandrillus_sphinx Macaca_mulatta', 'Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus Mandrillus_sphinx', 'Papio_anubis Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus', 'Macaca_mulatta Macaca_silenus Mandrillus_sphinx Cercopithecus_mona', 'Macaca_assamensis Macaca_mulatta Macaca_silenus Mandrillus_sphinx', 'Macaca_nemestrina Macaca_silenus Macaca_mulatta Mandrillus_sphinx', 'Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta Colobus_guereza', 'Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona Macaca_mulatta', 'Chlorocebus_aethiops Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona', 'Cercopithecus_mitis Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta', 'Colobus_guereza Trachypithecus_phayrei Macaca_mulatta Hylobates_lar', 'Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza Macaca_mulatta', 'Pygathrix_nemaeus Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza', 'Rhinopithecus_roxellana Rhinopithecus_strykeri Pygathrix_nemaeus Trachypithecus_phayrei', 'Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei Macaca_mulatta', 'Colobus_angolensis_palliatus Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei', 'Homo_sapiens Hylobates_lar Macaca_mulatta Saguinus_midas', 'Hylobates_lar Nomascus_leucogenys Homo_sapiens Macaca_mulatta', 'Hoolock_hoolock Hylobates_lar Nomascus_leucogenys Homo_sapiens', 'Hylobates_lar Symphalangus_syndactylus Hoolock_hoolock Nomascus_leucogenys', 'Hylobates_lar Hylobates_pileatus Symphalangus_syndactylus Hoolock_hoolock', 'Homo_sapiens Pongo_pygmaeus Hylobates_lar Macaca_mulatta', 'Gorilla_gorilla_gorilla Homo_sapiens Pongo_pygmaeus Hylobates_lar', 'Homo_sapiens Pan_troglodytes Gorilla_gorilla_gorilla Pongo_pygmaeus', 'Pan_paniscus Pan_troglodytes Homo_sapiens Gorilla_gorilla_gorilla', 'Pongo_abelii Pongo_pygmaeus Homo_sapiens Hylobates_lar']

# %%
def extract_label_R(clade):
    """
    This function returns the autosomal and sex chromosomal 
    ILS and symmetry index of each clade for the plot. It
    rounds the scores to 4 digits. If the branch has no score
    None is returned instead. 
    """
    
    # If the quartet was sent to the cluster
    if (isinstance(clade.other.tag, str)) and (len(clade.other.tag.split(' ')) == 4):
        # Extract scores from dictionary and format the output
        tag = [str("%.4f" % dct[clade.other.tag][i]) for i in dct[clade.other.tag]]
        return tag[0]+'www'+tag[1]+'nnn'+tag[2]+'www'+tag[3]+'xxx'
    
    elif clade.is_terminal() == False:
        return 'xxx'
    
    else:
        return clade.name

# %%
tree2 = PhyloXMLIO.read('../results/tree.xml')[0]

tree2 = tag_tree(tree2)

tree2.ladderize()

for clade in tree2.find_clades():
    clade.name = extract_label_R(clade)

Phylo.write(tree2, '../results/tree_2.new', 'newick')
# Out:
# ['Canis_familiaris Felis_catus Sus_scrofa Macaca_mulatta', 'Mus_musculus Oryctolagus_cuniculus Macaca_mulatta Sus_scrofa', 'Macaca_mulatta tree_shrew Mus_musculus Sus_scrofa', 'Lemur_catta Macaca_mulatta tree_shrew Mus_musculus', 'Lemur_catta Nycticebus_bengalensis Macaca_mulatta tree_shrew', 'Nycticebus_bengalensis Otolemur_garnettii Lemur_catta Macaca_mulatta', 'Loris_tardigradus Nycticebus_bengalensis Otolemur_garnettii Lemur_catta', 'Nycticebus_bengalensis Nycticebus_pygmaeus Loris_tardigradus Otolemur_garnettii', 'Galago_moholi Otolemur_garnettii Nycticebus_bengalensis Lemur_catta', 'Daubentonia_madagascariensis Lemur_catta Nycticebus_bengalensis Macaca_mulatta', 'Lemur_catta Microcebus_murinus Daubentonia_madagascariensis Nycticebus_bengalensis', 'Lemur_catta Prolemur_simus Microcebus_murinus Daubentonia_madagascariensis', 'Macaca_mulatta Saguinus_midas Lemur_catta tree_shrew', 'Pithecia_pithecia Saguinus_midas Macaca_mulatta Lemur_catta', 'Ateles_fusciceps Saguinus_midas Pithecia_pithecia Macaca_mulatta', 'Cebus_albifrons Saguinus_midas Ateles_fusciceps Pithecia_pithecia', 'Aotus_nancymaae Saguinus_midas Cebus_albifrons Ateles_fusciceps', 'Callithrix_jacchus Saguinus_midas Aotus_nancymaae Cebus_albifrons', 'Cebus_albifrons Sapajus_apella Saguinus_midas Ateles_fusciceps', 'Hylobates_lar Macaca_mulatta Saguinus_midas Lemur_catta', 'Colobus_guereza Macaca_mulatta Hylobates_lar Saguinus_midas', 'Cercopithecus_mona Macaca_mulatta Colobus_guereza Hylobates_lar', 'Macaca_mulatta Mandrillus_sphinx Cercopithecus_mona Colobus_guereza', 'Mandrillus_sphinx Papio_hamadryas Macaca_mulatta Cercopithecus_mona', 'Cercocebus_atys Mandrillus_sphinx Papio_hamadryas Macaca_mulatta', 'Mandrillus_leucophaeus Mandrillus_sphinx Cercocebus_atys Papio_hamadryas', 'Lophocebus_aterrimus Papio_hamadryas Mandrillus_sphinx Macaca_mulatta', 'Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus Mandrillus_sphinx', 'Papio_anubis Papio_hamadryas Theropithecus_gelada Lophocebus_aterrimus', 'Macaca_mulatta Macaca_silenus Mandrillus_sphinx Cercopithecus_mona', 'Macaca_assamensis Macaca_mulatta Macaca_silenus Mandrillus_sphinx', 'Macaca_nemestrina Macaca_silenus Macaca_mulatta Mandrillus_sphinx', 'Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta Colobus_guereza', 'Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona Macaca_mulatta', 'Chlorocebus_aethiops Chlorocebus_sabaeus Erythrocebus_patas Cercopithecus_mona', 'Cercopithecus_mitis Cercopithecus_mona Chlorocebus_sabaeus Macaca_mulatta', 'Colobus_guereza Trachypithecus_phayrei Macaca_mulatta Hylobates_lar', 'Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza Macaca_mulatta', 'Pygathrix_nemaeus Rhinopithecus_roxellana Trachypithecus_phayrei Colobus_guereza', 'Rhinopithecus_roxellana Rhinopithecus_strykeri Pygathrix_nemaeus Trachypithecus_phayrei', 'Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei Macaca_mulatta', 'Colobus_angolensis_palliatus Colobus_guereza Piliocolobus_tephrosceles Trachypithecus_phayrei', 'Homo_sapiens Hylobates_lar Macaca_mulatta Saguinus_midas', 'Hylobates_lar Nomascus_leucogenys Homo_sapiens Macaca_mulatta', 'Hoolock_hoolock Hylobates_lar Nomascus_leucogenys Homo_sapiens', 'Hylobates_lar Symphalangus_syndactylus Hoolock_hoolock Nomascus_leucogenys', 'Hylobates_lar Hylobates_pileatus Symphalangus_syndactylus Hoolock_hoolock', 'Homo_sapiens Pongo_pygmaeus Hylobates_lar Macaca_mulatta', 'Gorilla_gorilla_gorilla Homo_sapiens Pongo_pygmaeus Hylobates_lar', 'Homo_sapiens Pan_troglodytes Gorilla_gorilla_gorilla Pongo_pygmaeus', 'Pan_paniscus Pan_troglodytes Homo_sapiens Gorilla_gorilla_gorilla', 'Pongo_abelii Pongo_pygmaeus Homo_sapiens Hylobates_lar']
# 1
